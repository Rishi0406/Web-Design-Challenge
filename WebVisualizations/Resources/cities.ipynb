# %%
import pandas as pd

# %%
csv=pd.read_csv("cities.csv")
csv=csv.set_index("City_ID",drop=True)

# %%
html=csv.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#     <tr>
#       <th>City_ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>ewa beach</td>
#       <td>20</td>
#       <td>US</td>
#       <td>1598271896</td>
#       <td>74</td>
#       <td>21.32</td>
#       <td>-158.01</td>
#       <td>80.60</td>
#       <td>11.21</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>amurzet</td>
#       <td>100</td>
#       <td>RU</td>
#       <td>1598271896</td>
#       <td>96</td>
#       <td>47.70</td>
# ...

# %%
new_file = open("cities.html", "w")
new_file.write(html)
new_file.close()
